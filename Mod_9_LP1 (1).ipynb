# %% [markdown]
# # Lab 9: Linear Programming

# %% [markdown]
# Lab associated with Module 9: Linear Programming

# %% [markdown]
# ***

# %%
# The following lines are used to increase the width of cells to utilize more space on the screen 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# C:\Users\jarac\AppData\Local\Temp\ipykernel_14580\1945220536.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ***

# %% [markdown]
# ### Section 0: Imports

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ***

# %% [markdown]
# ### Section 1: Solving LP problem graphically

# %% [markdown]
# Let us see if we can solve the LP problem that we discussed in the lecture, graphically

# %%
X1 = np.linspace(0, 1000)

# %%
# X1 + X2 >= 200
# X2 = 200 - X1
X2 = 200 - X1

# %%
X2x = X1[np.where(X2 > 0)[0]]
X2y = X2[np.where(X2 > 0)[0]]

# %%
# 9X1 + 6X2 <= 1556
# X2 = (1556 - 9X1)/6

X3 = (1556 - 9*X1)/6

print(X3)

X3x = X1[np.where(X3 > 0)[0]]
X3y = X3[np.where(X3 > 0)[0]]
# Out:
# [  259.33333333   228.72108844   198.10884354   167.49659864
#    136.88435374   106.27210884    75.65986395    45.04761905
#     14.43537415   -16.17687075   -46.78911565   -77.40136054
#   -108.01360544  -138.62585034  -169.23809524  -199.85034014
#   -230.46258503  -261.07482993  -291.68707483  -322.29931973
#   -352.91156463  -383.52380952  -414.13605442  -444.74829932
#   -475.36054422  -505.97278912  -536.58503401  -567.19727891
#   -597.80952381  -628.42176871  -659.03401361  -689.6462585
#   -720.2585034   -750.8707483   -781.4829932   -812.0952381
#   -842.70748299  -873.31972789  -903.93197279  -934.54421769
#   -965.15646259  -995.76870748 -1026.38095238 -1056.99319728
#  -1087.60544218 -1118.21768707 -1148.82993197 -1179.44217687
#  -1210.05442177 -1240.66666667]

# %%
# 12X1 + 16X2 <= 2880
# X2 = (2880 - 12X1)/16

X4 = (2880 - 12*X1)/16

X4x = X1[np.where(X4 > 0)[0]]
X4y = X4[np.where(X4 > 0)[0]]

# %% [markdown]
# Let us plot these constraints

# %%
plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
plt.plot(X4x, X4y, label=r'$2y\geq25-x$')

plt.legend(['X1 + X2 >= 200', '9X1 + 6X2 <= 1556', '12X1 + 16X2 <= 2880'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# Let us see if we can plot the feasible region

# %%
plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
plt.plot(X4x, X4y, label=r'$2y\leq25-x$')

# Fill feasible region
y5 = np.minimum(X2y[0:9], X3y)
y6 = np.minimum(y5, X4y[0:9])
plt.fill_between(X4x[0:9], y6, color='grey', alpha=0.5)

plt.legend(['X1 + X2 >= 200', '9X1 + 6X2 <= 1556', '12X1 + 16X2 <= 2880'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# Okay, now we have the constraints, let us see if we can plot the various values of objective function

# %%
# 350X1 + 300X2
# X2 = (N - 350X1)/300
N1 = 12000
N2 = 35000
N3 = 50000
N4 = 70000

X5_1 = (N1 - 350*X1)/300
X5_2 = (N2 - 350*X1)/300
X5_3 = (N3 - 350*X1)/300
X5_4 = (N4 - 350*X1)/300

# Fill feasible region
y5 = np.minimum(X2y[0:9], X3y)
y6 = np.minimum(y5, X4y[0:9])
plt.fill_between(X4x[0:9], y6, color='grey', alpha=0.5)

# No need to plot the constraints

#plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
#plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
#plt.plot(X4x, X4y, label=r'$2y\leq25-x$')

X5_1x = X1[np.where(X5_1 > 0)[0]]
X5_1y = X5_1[np.where(X5_1 > 0)[0]]

X5_2x = X1[np.where(X5_2 > 0)[0]]
X5_2y = X5_2[np.where(X5_2 > 0)[0]]

X5_3x = X1[np.where(X5_3 > 0)[0]]
X5_3y = X5_3[np.where(X5_3 > 0)[0]]

X5_4x = X1[np.where(X5_4 > 0)[0]]
X5_4y = X5_4[np.where(X5_4 > 0)[0]]

plt.plot(X5_1x, X5_1y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_2x, X5_2y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_3x, X5_3y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_4x, X5_4y, '--', label=r'$2y\leq25-x$')

plt.legend(['12k', '35k', '50k', '70k','Feasible Region'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# ### <font color='red'> Activity 1: Code Reflections. </font>

# %% [markdown]
# $
# \begin{eqnarray}
# \textrm{max } && 350X_1 +  300X_2 \\
# \textrm{subject to } && X_1  + X_2 \leq 200 \\
# && 9 X_1 + 6 X_2 \leq 1556 \\
# && 12 X_1 + 16 X_2 \leq 2880 \\
# && X_1 \geq 0 \\
# && X_2 \geq 0
# \end{eqnarray}
# $

# %%
'''
There were two kinds of hot tubs represented by X1 and X2. X1 sales would lead to a profit of $350 per X1 hot tub. Concurrently, X2 hot tubs had an associated profit of $300 per X2 hot tub. 
The constraints included a max of 200 pumps for both hot tub types in this production cycle, 9 hours of labour per X1 hot tub, 6 hours of labour per X2 hot tub, a total of 1566 production hours available, 
12 feet of tubing per X1 hot tub, 16 feet of tubing per X2 hot tub, and 2880 feet of tubing available, all assuming that X1 and X2 hot tubs have a value greater than 0. 
The goal of the function is to determine a maximum of profits during the next production cycle.
The first graph shown plots all 3 constraints.
X1 + X2 <= 200 in Blue
9X1 + 6X2 <= 1556 in Orange
12X1 + 16X2 <= 2880 in Green
Graph 2 shows the feasible region that fits all the constraints in a shaded grey colour
Our values must reside within this region
The final graph plots the various values of the objective function, this graph does not plot the constraints

'''

# %% [markdown]
# ***

# %% [markdown]
# ### <font color='red'> Activity 2: Solve the LP given to you in the activity of Section II. </font>

# %% [markdown]
# $
# \begin{eqnarray}
# \textrm{max } && 4X_1 +  5X_2 \\
# \textrm{subject to } && 2X_1  + 3X_2 \leq 120 \\
# && 4 X_1 + 3 X_2 \leq 140 \\
# && X_1 + X_2 \geq 80 \\
# && X_1 \geq 0 \\
# && X_2 \geq 0
# \end{eqnarray}
# $

# %%
#### TODO ####
### Good Luck ###

X1 = np.linspace(0, 1000)

# %%
#2X1 + 3X2 <= 120
X2 = (60 - X1)/3
print(X2)
# Out:
# [  20.           13.19727891    6.39455782   -0.40816327   -7.21088435
#   -14.01360544  -20.81632653  -27.61904762  -34.42176871  -41.2244898
#   -48.02721088  -54.82993197  -61.63265306  -68.43537415  -75.23809524
#   -82.04081633  -88.84353741  -95.6462585  -102.44897959 -109.25170068
#  -116.05442177 -122.85714286 -129.65986395 -136.46258503 -143.26530612
#  -150.06802721 -156.8707483  -163.67346939 -170.47619048 -177.27891156
#  -184.08163265 -190.88435374 -197.68707483 -204.48979592 -211.29251701
#  -218.0952381  -224.89795918 -231.70068027 -238.50340136 -245.30612245
#  -252.10884354 -258.91156463 -265.71428571 -272.5170068  -279.31972789
#  -286.12244898 -292.92517007 -299.72789116 -306.53061224 -313.33333333]

# %%
X2x = X1[np.where(X2 > 0)[0]]
X2y = X2[np.where(X2 > 0)[0]]

# %%
#4X1 + 3X2 <= 120
#X2 = (140 - 4X1)/3
X3 = (140 - 4*X1)/3

print(X3)

X3x = X1[np.where(X3 >0)[0]]
X3y = X3[np.where(X3 > 0)[0]]
# Out:
# [   46.66666667    19.45578231    -7.75510204   -34.96598639
#    -62.17687075   -89.3877551   -116.59863946  -143.80952381
#   -171.02040816  -198.23129252  -225.44217687  -252.65306122
#   -279.86394558  -307.07482993  -334.28571429  -361.49659864
#   -388.70748299  -415.91836735  -443.1292517   -470.34013605
#   -497.55102041  -524.76190476  -551.97278912  -579.18367347
#   -606.39455782  -633.60544218  -660.81632653  -688.02721088
#   -715.23809524  -742.44897959  -769.65986395  -796.8707483
#   -824.08163265  -851.29251701  -878.50340136  -905.71428571
#   -932.92517007  -960.13605442  -987.34693878 -1014.55782313
#  -1041.76870748 -1068.97959184 -1096.19047619 -1123.40136054
#  -1150.6122449  -1177.82312925 -1205.03401361 -1232.24489796
#  -1259.45578231 -1286.66666667]

# %%
#X1 + X2 >= 80
#X2 = 80 - X1

X4 = 80 - X1

X4x = X1[np.where(X4 >0)[0]]
X4y = X4[np.where(X4 >0)[0]]

# %%
#Plotting the constraints
plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
plt.plot(X4x, X4y, label=r'$2y\geq25-x$')

plt.legend(['2X1 + 3X2 <= 120', '4X1 + 3X2 <= 140', 'X1 + X2 >= 80'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
#Plotting the feasible region
plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
plt.plot(X4x, X4y, label=r'$2y\geq25-x$')

y5 = np.minimum(X2y[0:2], X3y)
y6 = np.minimum(y5, X4y[0:2])

plt.fill_between(X1[0:2], X2y[0:2], color='blue', alpha=0.3)

plt.fill_between(X2x[0:2], X3y, color='red', alpha=0.3)

plt.fill_between(X1[0:2], [100,100], X4y[0:2], color='green', alpha=0.2)


plt.legend(['2X1 + 3X2 <= 120', '4X1 + 3X2 <= 140', 'X1 + X2 >= 80'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
#Plotting various values of the objective function
# 4X1 + 5X2
# X2 = (N - 4X1)/5
N1 = 50
N2 = 100
N3 = 200
N4 = 300

X5_1 = (N1 - 4*X1)/5
X5_2 = (N2 - 4*X1)/5
X5_3 = (N3 - 4*X1)/5
X5_4 = (N4 - 4*X1)/5

# Fill feasible region
y5 = np.minimum(X2y[0:2], X3y)
y6 = np.minimum(y5, X4y[0:2])
plt.fill_between(X4x[0:2], y6, color='grey', alpha=0.1)

# No need to plot the constraints

#plt.plot(X2x, X2y, label=r'$2y\leq25-x$')
#plt.plot(X3x, X3y, label=r'$2y\leq25-x$')
#plt.plot(X4x, X4y, label=r'$2y\geq25-x$')

X5_1x = X1[np.where(X5_1 > 0)[0]]
X5_1y = X5_1[np.where(X5_1 > 0)[0]]

X5_2x = X1[np.where(X5_2 > 0)[0]]
X5_2y = X5_2[np.where(X5_2 > 0)[0]]

X5_3x = X1[np.where(X5_3 > 0)[0]]
X5_3y = X5_3[np.where(X5_3 > 0)[0]]

X5_4x = X1[np.where(X5_4 > 0)[0]]
X5_4y = X5_4[np.where(X5_4 > 0)[0]]


plt.plot(X5_1x, X5_1y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_2x, X5_2y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_3x, X5_3y, '--', label=r'$2y\leq25-x$')
plt.plot(X5_4x, X5_4y, '--', label=r'$2y\leq25-x$')

plt.legend(['50 ','100', '200', '300','Feasible Region'])
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# ***

# %% [markdown]
# ### <font color='red'> Activity 3-8: Refer to Activities in the module. </font>

# %%
#Activities 3-8 Completed in Report PDF

# %% [markdown]
# ***
